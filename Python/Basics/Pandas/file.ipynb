# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    objectid                                globalid  \
# 0       100    c4b3155b-31a0-4e95-846f-fce09f245437
# 1      1000    753495d8-4429-43e5-85a3-dcf6230ef749
# 2     10000  {3842B5C5-EF04-41A4-8216-D6EA627DCE5E}
# 3     10001  {C212A0FC-C115-4425-8F95-931B12C5F86A}
# 4     10002  {DA48265D-7730-416F-8E1C-EBC8C8ACE2C2}
# 5     10003  {46F009AC-1DF9-4F39-8973-01E407466B67}
# 6     10004  {DA22A48D-3C12-4E33-895C-2E6F02CA4370}
# 7     10005  {B9E7740C-95B7-4992-81F5-437B17FF0627}
# 8     10006  {D90EC6E8-6D48-4A26-8DD0-2C64E4CB168A}
# 9     10007  {D727EBEB-48A4-4BAE-85E1-44F3355A8DDA}
#
#   Seating Interest (Sidewalk/Roadway/Both)                    Restaurant Name  \
# 0                                 sidewalk  Pomp and Circumstance Hospitality
# 1                                     both                          Charm Kao
# 2                              openstreets                   SAKE BAR HAGI 46
# ...

# %%
df[df['temp'] >= 20].groupby(['day']).first()
# Out:
#           temp condition
# day
# Friday      20     sunny
# Saturday    22    cloudy
# Sundy       24      rain
